# %% [markdown]
# ## Reference
# - [Deep Learning with Keras](https://github.com/PacktPublishing/Deep-Learning-with-Keras)
# - [直感 Deep Learning](https://github.com/oreilly-japan/deep-learning-with-keras-ja)

# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

# %%
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
OPTIMIZER = SGD()
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2
DROPOUT = 0.3

# %%
# data:
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# 28 × 28 = 784
RESHAPED = 784

# %%
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
np.random.seed(1671) # for reproducibility

# %%
# convert class vectors to binary class metrics
Y_train = tf.keras.utils.to_categorical(y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(y_test, NB_CLASSES)

# %%
# Add hidden layers
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               100480
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])

# %%
model.fit(X_train, Y_train,
          batch_size=BATCH_SIZE, epochs=NB_EPOCH,
          verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 5s 99us/sample - loss: 1.7393 - accuracy: 0.4447 - val_loss: 0.9316 - val_accuracy: 0.8292
# Epoch 2/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.9301 - accuracy: 0.7166 - val_loss: 0.5274 - val_accuracy: 0.8770
# Epoch 3/20
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.6955 - accuracy: 0.7866 - val_loss: 0.4194 - val_accuracy: 0.8928
# Epoch 4/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.5944 - accuracy: 0.8187 - val_loss: 0.3670 - val_accuracy: 0.9003
# Epoch 5/20
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.5319 - accuracy: 0.8403 - val_loss: 0.3350 - val_accuracy: 0.9073
# Epoch 6/20
# 48000/48000 [==============================] - 4s 76us/sample - loss: 0.4879 - accuracy: 0.8545 - val_loss: 0.3119 - val_accuracy: 0.9121
# Epoch 7/20
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.4584 - accuracy: 0.8623 - val_loss: 0.2942 - val_accuracy: 0.9169
# Epoch 8/20
# 48000/48000 [==============================] - 4s 80us/sample - loss: 0.4353 - accuracy: 0.8706 - val_loss: 0.2794 - val_accuracy: 0.9205
# Epoch 9/20
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.4111 - accuracy: 0.8782 - val_loss: 0.2676 - val_accuracy: 0.9246
# Epoch 10/20
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.3905 - accuracy: 0.8864 - val_loss: 0.2565 - val_accuracy: 0.9271
# Epoch 11/20
# 48000/48000 [==============================] - 4s 80us/sample - loss: 0.3785 - accuracy: 0.8884 - val_loss: 0.2473 - val_accuracy: 0.9303
# Epoch 12/20
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.3646 - accuracy: 0.8941 - val_loss: 0.2379 - val_accuracy: 0.9317
# Epoch 13/20
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.3503 - accuracy: 0.8972 - val_loss: 0.2297 - val_accuracy: 0.9334
# Epoch 14/20
# 48000/48000 [==============================] - 4s 91us/sample - loss: 0.3403 - accuracy: 0.9001 - val_loss: 0.2231 - val_accuracy: 0.9358
# Epoch 15/20
# 48000/48000 [==============================] - 4s 87us/sample - loss: 0.3290 - accuracy: 0.9024 - val_loss: 0.2167 - val_accuracy: 0.9372
# Epoch 16/20
# 48000/48000 [==============================] - 4s 82us/sample - loss: 0.3195 - accuracy: 0.9075 - val_loss: 0.2101 - val_accuracy: 0.9389
# Epoch 17/20
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.3114 - accuracy: 0.9092 - val_loss: 0.2049 - val_accuracy: 0.9410
# Epoch 18/20
# 48000/48000 [==============================] - 4s 79us/sample - loss: 0.3032 - accuracy: 0.9121 - val_loss: 0.1999 - val_accuracy: 0.9424
# Epoch 19/20
# 48000/48000 [==============================] - 4s 80us/sample - loss: 0.2963 - accuracy: 0.9122 - val_loss: 0.1947 - val_accuracy: 0.9432
# Epoch 20/20
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.2886 - accuracy: 0.9150 - val_loss: 0.1900 - val_accuracy: 0.9453

# %%
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
#
# Test score: 0.19195680053681136
# Test accuracy: 0.9456
