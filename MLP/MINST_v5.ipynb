# %% [markdown]
# ## Reference
# - [Deep Learning with Keras](https://github.com/PacktPublishing/Deep-Learning-with-Keras)
# - [直感 Deep Learning](https://github.com/oreilly-japan/deep-learning-with-keras-ja)

# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam

# %%
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
OPTIMIZER = Adam()
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2
DROPOUT = 0.3

# %%
# data:
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# 28 × 28 = 784
RESHAPED = 784

# %%
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
np.random.seed(1671) # for reproducibility

# %%
# convert class vectors to binary class metrics
Y_train = tf.keras.utils.to_categorical(y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(y_test, NB_CLASSES)

# %%
# Add hidden layers
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# activation (Activation)      (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])

# %%
model.fit(X_train, Y_train,
          batch_size=BATCH_SIZE, epochs=NB_EPOCH,
          verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 6s 118us/sample - loss: 0.5257 - accuracy: 0.8398 - val_loss: 0.1944 - val_accuracy: 0.9427
# Epoch 2/20
# 48000/48000 [==============================] - 5s 96us/sample - loss: 0.2326 - accuracy: 0.9309 - val_loss: 0.1358 - val_accuracy: 0.9606
# Epoch 3/20
# 48000/48000 [==============================] - 5s 112us/sample - loss: 0.1781 - accuracy: 0.9476 - val_loss: 0.1131 - val_accuracy: 0.9668
# Epoch 4/20
# 48000/48000 [==============================] - 6s 122us/sample - loss: 0.1472 - accuracy: 0.9559 - val_loss: 0.1026 - val_accuracy: 0.9687
# Epoch 5/20
# 48000/48000 [==============================] - 4s 90us/sample - loss: 0.1282 - accuracy: 0.9605 - val_loss: 0.1012 - val_accuracy: 0.9698
# Epoch 6/20
# 48000/48000 [==============================] - 5s 102us/sample - loss: 0.1179 - accuracy: 0.9635 - val_loss: 0.0898 - val_accuracy: 0.9721
# Epoch 7/20
# 48000/48000 [==============================] - 5s 108us/sample - loss: 0.1045 - accuracy: 0.9679 - val_loss: 0.0857 - val_accuracy: 0.9738
# Epoch 8/20
# 48000/48000 [==============================] - 5s 96us/sample - loss: 0.0992 - accuracy: 0.9701 - val_loss: 0.0826 - val_accuracy: 0.9758
# Epoch 9/20
# 48000/48000 [==============================] - 4s 93us/sample - loss: 0.0889 - accuracy: 0.9714 - val_loss: 0.0806 - val_accuracy: 0.9765
# Epoch 10/20
# 48000/48000 [==============================] - 4s 92us/sample - loss: 0.0845 - accuracy: 0.9737 - val_loss: 0.0799 - val_accuracy: 0.9770
# Epoch 11/20
# 48000/48000 [==============================] - 4s 92us/sample - loss: 0.0785 - accuracy: 0.9749 - val_loss: 0.0864 - val_accuracy: 0.9749
# Epoch 12/20
# 48000/48000 [==============================] - 4s 92us/sample - loss: 0.0768 - accuracy: 0.9753 - val_loss: 0.0826 - val_accuracy: 0.9754
# Epoch 13/20
# 48000/48000 [==============================] - 5s 96us/sample - loss: 0.0694 - accuracy: 0.9778 - val_loss: 0.0802 - val_accuracy: 0.9770
# Epoch 14/20
# 48000/48000 [==============================] - 4s 93us/sample - loss: 0.0670 - accuracy: 0.9781 - val_loss: 0.0792 - val_accuracy: 0.9787
# Epoch 15/20
# 48000/48000 [==============================] - 5s 95us/sample - loss: 0.0641 - accuracy: 0.9787 - val_loss: 0.0817 - val_accuracy: 0.9775
# Epoch 16/20
# 48000/48000 [==============================] - 5s 94us/sample - loss: 0.0638 - accuracy: 0.9794 - val_loss: 0.0803 - val_accuracy: 0.9782
# Epoch 17/20
# 48000/48000 [==============================] - 4s 93us/sample - loss: 0.0583 - accuracy: 0.9810 - val_loss: 0.0804 - val_accuracy: 0.9779
# Epoch 18/20
# 48000/48000 [==============================] - 5s 95us/sample - loss: 0.0559 - accuracy: 0.9816 - val_loss: 0.0810 - val_accuracy: 0.9794
# Epoch 19/20
# 48000/48000 [==============================] - 5s 94us/sample - loss: 0.0552 - accuracy: 0.9818 - val_loss: 0.0799 - val_accuracy: 0.9789
# Epoch 20/20
# 48000/48000 [==============================] - 4s 93us/sample - loss: 0.0547 - accuracy: 0.9816 - val_loss: 0.0850 - val_accuracy: 0.9776

# %%
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
#
# Test score: 0.07442035688784818
# Test accuracy: 0.9795
